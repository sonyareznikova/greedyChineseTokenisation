# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import gutenberg

# %%
text = gutenberg.raw("carroll-alice.txt")
print("\n".join(gutenberg.fileids()))
# Out:
# austen-emma.txt
# austen-persuasion.txt
# austen-sense.txt
# bible-kjv.txt
# blake-poems.txt
# bryant-stories.txt
# burgess-busterbrown.txt
# carroll-alice.txt
# chesterton-ball.txt
# chesterton-brown.txt
# chesterton-thursday.txt
# edgeworth-parents.txt
# melville-moby_dick.txt
# milton-paradise.txt
# shakespeare-caesar.txt
# shakespeare-hamlet.txt
# shakespeare-macbeth.txt
# whitman-leaves.txt

# %%
import re

# %%
t = re.split(" | \n | --", text)

# %%
print(len(t))
# Out:
# 25056

# %%
nltk.download()

# %%
len(nltk.word_tokenize(text))
# Out:
# 33310

# %%
#reading the phrases
init_text_file = open("1-tok/chinesetext.utf8", "r")
init_text = []
for line in init_text_file:
    init_text.append(line[:len(line)-1])
print("init text")
print(init_text[0:5])
init_text_file.close()
# Out:
# init text
# ['一', '友情', '嘉珍和我住在同一條巷子', '我們是鄰居', '也是同班同學']

# %%
#reading the wordlist
wordlist_file = open("1-tok/chinesetrad_wordlist.utf8", "r")
wordlist = []
for line in wordlist_file:
    wordlist.append(line[:len(line)-1])
print("word list")
print(wordlist[:40])
wordlist_file.close()
# Out:
# word list
# ['10月', '5日', 'JlnＢｕｋｉｔＢｉｎｔａｎｇ', 'Nab', 'Nac', '○‧七二個', '、', '一', '一一', '一一九', '一七九六', '一下', '一下子', '一串', '一九0三年', '一九七四年', '一九七年代', '一九七０', '一九七０年代', '一九三六年', '一九三０年', '一九九一年', '一九九二', '一九九二年', '一九九四年', '一九九０年', '一九二四年', '一九五二年', '一九八三年', '一九八二年', '一九八五年', '一九八八年', '一九八四年', '一九０一年', '一些', '一件', '一份', '一位', '一併', '一個']

# %%
def greedy_tokenizer_chinese(n, text):
    tokens = []
    #iterating over all phrases
    for sentence in text:
        end_number = n
        #iterating over symbols
        this_sentence_tokens = []
        start_index = 0
        while (start_index < len(sentence)):
            if sentence[start_index:start_index+end_number] in wordlist:
                this_sentence_tokens.append(sentence[start_index:start_index+end_number])
                start_index += end_number
            else:
                while end_number > 0:
                    if sentence[start_index:start_index+end_number] in wordlist or end_number == 1:
                        this_sentence_tokens.append(sentence[start_index:start_index+end_number])
                        start_index += end_number
                        end_number = n
                        break
                    else:
                        end_number -= 1
        tokens.append(this_sentence_tokens)
    return tokens

# %%
tokens = greedy_tokenizer_chinese(4, init_text)
# Out:
# [['一'],
#  ['友情'],
#  ['嘉珍', '和', '我', '住在', '同一條', '巷子'],
#  ['我們', '是', '鄰居'],
#  ['也', '是', '同班', '同學'],
#  ['我們', '常常', '一起', '上學'],
#  ['一起', '回家'],
#  ['有一天'],
#  ['上學', '時'],
#  ['我', '到', '她', '家', '等候'],
#  ['按', '了', '門鈴'],
#  ['卻', '沒有', '任何', '動靜'],
#  ['正當', '我', '想', '離開', '時'],
#  ['門', '內', '突然', '傳來', '急促', '的', '腳步聲'],
#  ['嘉珍', '打開', '了', '門'],
#  ['大聲', '的', '叫', '著'],
#  ['快點'],
#  ['我', '媽媽', '暈倒', '了'],
#  ['嘉珍', '抓起', '我', '的', '手'],
#  ['急忙', '往', '屋', '裡', '跑'],
#  ['進入', '房間'],
#  ['看到', '她', '的', '媽媽', '趴', '在', '地上'],
#  ['臉色', '蒼白', '得', '像', '紙', '一樣'],
#  ['這種', '情景', '把', '我', '嚇壞', '了'],
#  ['怎麼辦'],
#  ['嘉珍', '不停', '的', '哭泣'],
#  ['聲音', '有些', '顫抖'],
#  ['我', '的', '腦海', '中', '頓時', '一片', '空白'],
#  ['不', '曉得', '怎麼辦', '才', '好'],
#  ['過', '了', '一會兒'],
#  ['我', '才', '問', '她'],
#  ['你', '爸爸', '呢'],
#  ['他', '出差', '了'],
#  ['嘉珍', '擦', '著', '眼淚'],
#  ['我', '握住', '她', '的', '雙手'],
#  ['她', '的', '手', '又', '冰', '又', '冷'],
#  ['這時'],
#  ['有個', '念頭', '突然', '閃過', '我', '的', '眼前'],
#  ['我', '幫', '她', '撥', '了', '一一九', '請', '救護車', '來'],
#  ['而且', '拍拍', '她', '的', '背'],
#  ['安慰', '她'],
#  ['不要', '著急'],
#  ['我', '會', '陪', '你', '的'],
#  ['不久'],
#  ['救護車', '停', '在', '她', '家', '門口'],
#  ['醫護', '人員', '很', '快', '的', '將', '她', '的', '媽媽', '抬上', '救護車'],
#  ['嘉珍', '上車', '前'],
#  ['對', '我', '說'],
#  ['謝謝', '你', '的', '幫忙'],
#  ['我', '握', '著', '她', '的', '手', '說'],
#  ['不用', '謝', '我'],
#  ['因為', '我們', '是', '好朋友'],
#  ['二'],
#  ['無私', '的', '愛'],
#  ['愛', '像', '火紅', '的', '太陽'],
#  ['散發', '光', '和', '熱'],
#  ['讓', '大地', '充滿', '生機'],
#  ['充滿', '希望'],
#  ['愛', '是', '生命', '的', '原動力'],
#  ['史懷哲', '醫生'],
#  ['踏遍', '落後', '貧困', '的', '地區'],
#  ['燃起', '病患', '重生', '的', '希望'],
#  ['愛', '是', '和平', '的', '基礎'],
#  ['德蕾莎', '修女'],
#  ['承擔', '千萬', '窮人', '的', '苦難'],
#  ['溫暖', '無數', '受傷', '的', '心靈'],
#  ['他們', '奉獻', '真愛'],
#  ['他們', '散播', '熱情'],
#  ['肯定', '了', '生命', '的', '價值'],
#  ['讓', '我們', '學習', '付出'],
#  ['讓', '我們', '學習', '關懷'],
#  ['生命', '才', '能', '綻放', '光輝'],
#  ['三'],
#  ['愛', '的', '傳承'],
#  ['天', '剛', '亮'],
#  ['江', '巡撫', '坐在', '書桌', '前', '看書'],
#  ['有一個', '侍官', '交給', '他', '一封', '信'],
#  ['江', '巡撫', '看', '了', '信'],
#  ['原來', '是', '一個', '書生', '要', '進京', '趕考'],
#  ['因為', '缺乏', '旅費'],
#  ['希望', '到', '府中', '做工'],
#  ['江', '巡撫', '放下', '信'],
#  ['看', '著', '窗', '外', '隨', '風', '飄動', '的', '樹枝'],
#  ['回想', '起', '二十年', '前', '的', '往事'],
#  ['二十年', '前'],
#  ['他', '在', '一個', '員外', '家', '做工'],
#  ['賺取', '趕考', '進京', '的', '旅費'],
#  ['白天'],
#  ['他', '必須', '做', '一些', '粗重', '的', '工作'],
#  ['晚上'],
#  ['他', '還', '得', '挑燈', '夜', '讀'],
#  ['準備', '參加', '考試'],
#  ['考試', '的', '日子', '快', '到了'],
#  ['可是', '他', '的', '心情', '卻', '很', '沉重'],
#  ['當', '他', '正', '為了', '缺乏', '旅費', '而', '發愁', '的', '時候'],
#  ['員外', '來', '找', '他'],
#  ['並且', '對', '他', '說'],
#  ['我', '看', '你', '悶悶不樂'],
#  ['是不是', '進京', '趕考', '的', '旅費', '不', '夠'],
#  ['這裡', '有', '一些', '銀子'],
#  ['你', '帶', '在', '身上'],
#  ['立刻', '動身', '去', '趕考', '吧'],
#  ['他', '接過', '銀子'],
#  ['感動', '得', '說不出', '話', '來'],
#  ['後來'],
#  ['他', '果然', '金榜題名'],
#  ['當', '他', '帶', '著', '禮物', '和', '銀子', '向', '員外', '道謝', '時'],
#  ['員外', '握', '著', '他', '的', '手', '說'],
#  ['你', '不用', '還', '我', '了'],
#  ['我', '只是', '盡', '一份', '心力', '而已'],
#  ['以後', '有', '機會'],
#  ['希望', '你', '也', '能夠', '幫助', '別人'],
#  ['江', '巡撫', '正', '想', '得', '入神'],
#  ['突然', '聽到', '一聲'],
#  ['大人'],
#  ['江', '巡撫', '回過神', '對', '侍官', '說'],
#  ['快', '請', '書生', '進來'],
#  ['書生', '低著頭'],
#  ['慢慢', '的', '走到', '他', '的', '面前'],
#  ['江', '巡撫', '對', '書生', '說'],
#  ['不要', '錯過', '今年', '的', '考試'],
#  ['這些', '銀子'],
#  ['你', '就', '帶', '在', '身上'],
#  ['動身', '趕考', '吧'],
#  ['書生', '用', '顫抖', '的', '手', '接過', '銀子'],
#  ['含', '著', '眼淚', '說'],
#  ['謝謝', '您'],
#  ['我', '不知道', '要', '怎麼', '來', '報答', '您'],
#  ['江', '巡撫', '說'],
#  ['你', '不必', '謝', '我'],
#  ['也', '不必', '回報', '我'],
#  ['四'],
#  ['快樂', '的', '閱讀課'],
#  ['上', '國語課', '的', '時候'],
#  ['老師', '叫', '我們', '這一組', '做', '讀書', '心得', '報告'],
#  ['我', '第一個', '站起來', '發言'],
#  ['我們', '閱讀', '的', '好', '書', '是', '小', '王子'],
#  ['這', '是', '法國人', '聖修伯里', '的', '作品'],
#  ['書', '中', '畫滿', '了', '可愛', '的', '插圖'],
#  ['小', '王子', '的', '外型', '很', '討人喜歡'],
#  ['這本', '書', '的', '內容', '是', '說'],
#  ['一個', '飛行員', '在', '非洲', '沙漠', '裡'],
#  ['遇見', '了', '小', '王子'],
#  ['小', '王子', '告訴', '他', '在', '星球', '旅行', '的', '經過'],
#  ['兩', '人', '成為', '知心', '的', '朋友'],
#  ['我', '說完', '之後'],
#  ['組長', '站起來', '補充', '說'],
#  ['小', '王子', '是', '一個', '可愛', '的', '人'],
#  ['他', '在', '小', '行星', '上'],
#  ['每天', '照顧', '會', '說話', '的', '玫瑰花', '、', '清理', '火山灰'],
#  ['而且', '欣賞', '落日'],
#  ['我', '喜歡', '這種', '自由自在', '的', '生活'],
#  ['明珠', '說'],
#  ['這本', '書', '最', '精采', '的', '部分'],
#  ['遇到', '許多', '不同', '類型', '的', '人'],
#  ['有',
#   '自大',
#   '先生',
#   '、',
#   '愛',
#   '下',
#   '命令',
#   '的',
#   '國王',
#   '、',
#   '賣',
#   '解渴丸',
#   '的',
#   '商人',
#   '等'],
#  ['小', '王子', '不', '喜歡', '自大', '的', '人'],
#  ['也', '不', '喜歡', '虛偽', '的', '人'],
#  ['我', '覺得', '小', '王子', '很', '正直'],
#  ['最後'],
#  ['阿平', '說'],
#  ['這本', '書', '中'],
#  ['有', '許多', '值得', '思考', '的', '句子'],
#  ['例如'],
#  ['狐狸', '告訴', '小', '王子'],
#  ['重要', '的', '東西', '不能', '只', '靠', '眼睛', '去', '看'],
#  ['只有', '用心', '去', '體會'],
#  ['才', '能', '看到', '事物', '的', '真相'],
#  ['這', '是', '我', '閱讀', '小', '王子', '最', '大', '的', '收穫'],
#  ['我們', '這一組', '報告完', '之後'],
#  ['獲得', '同學', '熱烈', '的', '掌聲'],
#  ['老師', '說'],
#  ['這一組', '小朋友', '不但', '說', '了', '這本', '書', '的', '大意'],
#  ['而且', '說出', '心得', '感想'],
#  ['也', '提到', '書', '中的', '好', '句子'],
#  ['有', '了', '這三項'],
#  ['再', '寫出', '作者', '和', '出版社'],
#  ['就是', '一份', '完整', '的', '讀書', '報告', '了'],
#  ['收穫', '很多'],
#  ['五'],
#  ['書', '的', '誕生'],
#  ['書'],
#  ['是', '人類', '的', '好朋友'],
#  ['它', '用來', '表達', '作者', '的', '思想', '和', '情感'],
#  ['更', '用來', '傳播', '知識'],
#  ['是', '怎樣', '誕生', '的', '呢'],
#  ['人類', '有', '了', '文字', '以後'],
#  ['用', '文字', '表達', '思想', '和', '情感'],
#  ['這些', '文字', '最早', '是', '刻', '在', '竹片', '或', '木片', '上'],
#  ['古人', '稱為', '冊'],
#  ['冊', '太', '重', '了'],
#  ['於是', '人們', '把', '文字', '寫', '在', '絲', '上'],
#  ['稱為', '帛書'],
#  ['絲', '很', '貴'],
#  ['聰明', '的', '祖先', '又', '發明', '了', '紙'],
#  ['過去', '人們', '用', '手抄', '的', '方式', '寫', '書'],
#  ['到了', '唐代'],
#  ['開始', '用', '印刷術', '印', '書'],
#  ['現在', '印刷術', '越來越', '進步'],
#  ['人們', '可以', '讀到', '更', '精美', '、', '更多', '樣', '的', '書'],
#  ['書', '是', '怎樣', '完成', '的', '呢'],
#  ['作者', '把', '文章', '送到', '印刷廠'],
#  ['進行', '電腦', '打字', '和', '排版'],
#  ['接著', '是', '校對', '的', '工作'],
#  ['校對', '之後', '再', '加上', '插圖'],
#  ['就', '可以', '印刷', '了'],
#  ['印刷', '和', '紙', '有', '密切', '的', '關係'],
#  ['不管', '是', '銅版紙', '或是', '道林紙'],
#  ['都', '各', '具', '特色'],
#  ['等到', '散發', '著', '油墨', '芳香', '的', '紙張', '裝釘成冊', '後'],
#  ['加上', '封面'],
#  ['就', '完成', '了'],
#  ['如果', '作者', '是', '書', '的', '母親'],
#  ['印刷廠', '就是', '產婆'],
#  ['兩者', '同等', '重要'],
#  ['還要', '為', '它', '辦理', '一張', '身分證'],
#  ['那', '就是', '版權頁'],
#  ['放', '在', '書', '的', '後面'],
#  ['有', '了', '它'],
#  ['新書', '就', '可以', '合法', '的', '和', '讀者', '見面', '了'],
#  ['六'],
#  ['拜訪', '書', '的', '家'],
#  ['阿群', '是', '我們', '班', '上', '的', '風雲人物'],
#  ['不但', '功課', '好'],
#  ['而且', '很', '熱心'],
#  ['他', '參加', '校', '內', '的', '科展', '、', '演講', '、', '查', '資料', '比賽'],
#  ['常常', '拿', '第一'],
#  ['同學們', '都', '說', '他', '有一個', '金', '頭腦'],
#  ['然而', '阿群', '總是', '客氣', '的', '說'],
#  ['我', '只是', '知道', '知識', '的', '寶庫', '在', '哪裡'],
#  ['常常', '去', '使用', '它', '而已'],
#  ['一個', '假日'],
#  ['阿群', '邀', '我', '去', '圖書館'],
#  ['走入', '寬敞', '的', '閱覽室'],
#  ['空氣', '中', '飄送', '著', '淡淡', '的', '書香'],
#  ['我', '第一眼', '就', '看到', '新書', '展示架', '上'],
#  ['放', '著', '許多', '才', '出版', '的', '書', '和', '雜誌'],
#  ['再', '往', '裡面', '走'],
#  ['一座座', '書架', '上', '放', '著', '各類', '圖書'],
#  ['有', '精裝', '書', '、', '平裝', '書'],
#  ['這兒', '就', '像', '一個', '書籍', '的', '大家', '庭'],
#  ['圖書館', '不但', '是', '書', '的', '家'],
#  ['而且', '是', '舉辦', '書香', '活動', '的', '好', '地方'],
#  ['當天'],
#  ['我們', '參加', '活用', '工具書', '的', '比賽'],
#  ['抽中', '的', '題目', '是', '臺灣', '有', '哪些', '列入', '保育', '的', '鳥類'],
#  ['我', '原本', '打算', '在', '自然', '科學類', '中', '找', '答案'],
#  ['阿群', '建議'],
#  ['先', '查尋', '期刊', '索引'],
#  ['來', '找', '相關', '資料'],
#  ['找到', '黑面琵鷺', '等', '保育', '鳥類', '的', '報導'],
#  ['由於', '我們', '快速', '的', '找到', '完整', '的', '資料'],
#  ['所以', '得到', '優等'],
#  ['阿群', '真', '不愧', '是', '個', '查', '資料', '的', '高手'],
#  ['我', '打從', '心', '裡', '佩服', '他'],
#  ['走出', '圖書館'],
#  ['我', '向', '阿群', '說'],
#  ['現在', '我', '知道', '了'],
#  ['也', '是', '知識', '的', '寶庫'],
#  ['以後', '我', '要', '常', '來', '拜訪', '它'],
#  ['七'],
#  ['登山'],
#  ['今年', '的', '重陽節', '正好', '是', '星期天'],
#  ['爸爸', '帶', '著', '我們', '全家', '去', '爬山'],
#  ['爸爸', '說'],
#  ['中國人', '都', '以', '登高', '來', '慶祝', '這個', '日子'],
#  ['來到', '山腳', '下'],
#  ['已經', '看到', '許多', '人', '踩', '著', '陽光'],
#  ['陸陸續續', '的', '登上', '山路', '了'],
#  ['走到', '半', '山', '上'],
#  ['看到', '一個', '年輕人'],
#  ['站', '在', '路', '旁'],
#  ['滿頭大汗'],
#  ['氣喘如牛'],
#  ['爸爸', '走到', '年輕人', '的', '身邊'],
#  ['關心', '的', '問', '他'],
#  ['年輕人', '啊'],
#  ['怎麼', '才', '走到', '山腰', '就', '走不動', '了', '呢'],
#  ['年輕人', '擦', '著', '汗水'],
#  ['不好意思', '的', '說'],
#  ['爬山', '好', '累'],
#  ['我', '的', '腿', '已經', '不聽使喚', '了'],
#  ['氣', '也', '喘不過來', '了'],
#  ['山路', '不', '難', '走'],
#  ['你', '走不動', '是', '因為', '平常', '運動', '太少', '了'],
#  ['年輕人', '嘆', '了', '一口氣', '說'],
#  ['唉'],
#  ['沒辦法'],
#  ['平日', '工作', '太', '忙碌', '了'],
#  ['沒', '時間', '運動'],
#  ['爸爸', '笑', '著', '說'],
#  ['一個', '人', '不能', '只有', '工作'],
#  ['休閒', '和', '運動', '也', '很', '重要', '的'],
#  ['登山', '是', '很', '好', '的', '運動'],
#  ['可以', '呼吸', '新鮮', '空氣'],
#  ['可以', '鍛鍊', '身體'],
#  ['還可以', '欣賞', '美麗', '的', '風景'],
#  ['你', '說', '是不是', '啊'],
#  ['年輕人', '伸展', '了', '雙臂'],
#  ['深深', '的', '吸', '了', '一口氣', '說'],
#  ['真的'],
#  ['山', '上', '的', '空氣', '真', '好'],
#  ['爸爸', '轉過身', '對', '我們', '說'],
#  ['要', '多', '運動'],
#  ['身體', '才', '健康'],
#  ['有', '健康', '的', '身體'],
#  ['讀書', '工作', '才', '會', '有效', '率'],
#  ['這時', '我', '看到', '年輕人', '望', '了', '爸爸', '說'],
#  ['您', '臉色', '紅潤'],
#  ['精力', '充沛'],
#  ['一定', '是', '常', '運動', '囉'],
#  ['只', '見', '爸爸', '得意', '的', '回答'],
#  ['嗯'],
#  ['我', '早睡早起'],
#  ['每天', '做', '體操'],
#  ['假日', '就', '帶', '家人', '爬山'],
#  ['享受', '可貴', '的', '森林浴'],
#  ['運動', '帶給', '我', '舒適', '和', '健康', '的', '生活'],
#  ['年輕人', '點點頭'],
#  ['好像', '已經', '找到', '健康', '的', '途徑', '了'],
#  ['爸爸', '拍拍', '年輕人', '的', '肩', '說'],
#  ['加油', '吧'],
#  ['我們', '一起', '登山', '慶祝', '重陽', '佳節'],
#  ['我們', '一步', '一步', '的', '向', '山', '上', '前進'],
#  ['八'],
#  ['健康', '四則'],
#  ['踢踢腿', '來', '彎彎腰'],
#  ['我們', '一起', '作', '體操'],
#  ['一', '、', '二', '、', '三', '、', '四'],
#  ['二', '、', '二', '、', '三', '、', '四'],
#  ['天天', '運動', '精神', '好'],
#  ['身體', '健康', '沒', '煩惱'],
#  ['早餐', '吃', '得', '好'],
#  ['營養', '均衡', '很', '重要'],
#  ['午餐', '吃', '得', '飽'],
#  ['魚肉', '蔬菜', '不可', '少'],
#  ['晚餐', '吃', '得', '巧'],
#  ['腸胃', '休息', '睡得著'],
#  ['拒絕', '煙'],
#  ['拒絕', '酒'],
#  ['檳榔', '更', '是', '不', '入', '口'],
#  ['毒品', '傷身', '又', '害命'],
#  ['嘗試', '之後', '易', '上鉤'],
#  ['快', '向', '它們', '說', '聲', '不'],
#  ['青春', '歲月', '才', '長久'],
#  ['吸收', '新', '知識'],
#  ['態度', '認真', '又', '積極'],
#  ['多', '交', '好朋友'],
#  ['接納', '別人', '的', '建議'],
#  ['肯定', '自己', '的', '能力'],
#  ['心理', '要', '健康'],
#  ['生活', '才', '能', '有意', '義'],
#  ['九'],
#  ['探病'],
#  ['一向', '健康', '活潑', '的', '小', '阿姨'],
#  ['竟然', '生病', '住院', '了'],
#  ['媽媽', '知道', '這個', '消息'],
#  ['心', '裡', '很', '著急'],
#  ['趕緊', '帶', '著', '我'],
#  ['到', '醫院', '探病'],
#  ['媽媽', '在', '醫院', '大門', '旁', '的', '水果店'],
#  ['買', '了', '一盒', '蘋果', '禮盒'],
#  ['小', '阿姨', '喜歡', '吃', '蘋果'],
#  ['等一下', '看到', '她'],
#  ['你', '就', '先', '把', '蘋果', '送給', '她'],
#  ['祝', '她', '平平安安'],
#  ['早日', '康復'],
#  ['走進', '醫院'],
#  ['搭', '電梯', '上', '了', '五樓'],
#  ['看到', '有的', '病人', '骨瘦如柴', '的', '躺', '在', '床', '上'],
#  ['有的', '病人', '在', '打點滴'],
#  ['看到', '這', '許多', '失去', '健康', '的', '人'],
#  ['我', '的', '心', '裡', '很', '難過'],
#  ['找到', '小', '阿姨', '的', '病房'],
#  ['媽媽', '趕緊', '走向', '床', '邊'],
#  ['拉', '著', '她', '的', '手'],
#  ['輕輕', '的', '問'],
#  ['現在', '好', '一點兒', '了', '嗎'],
#  ['小', '阿姨', '紅', '著', '眼眶', '說'],
#  ['本來', '只是', '輕微', '的', '感冒'],
#  ['我', '相信', '了', '藥品', '廣告'],
#  ['就', '隨便', '買', '成藥', '吃'],
#  ['後來', '全身', '紅腫'],
#  ['又', '癢', '又', '痛'],
#  ['醫師', '告訴', '我'],
#  ['不', '該', '自己', '亂', '吃', '藥'],
#  ['媽媽', '安慰', '小', '阿姨', '說'],
#  ['現在', '妳', '要', '安心', '養病'],
#  ['聽從', '醫師', '的', '吩咐'],
#  ['好好', '接受', '治療'],
#  ['身體', '就', '會', '很', '快', '的', '恢復', '健康'],
#  ['離開', '醫院'],
#  ['在', '回家', '的', '路', '上'],
#  ['看到', '來來往往', '的', '行人'],
#  ['我', '才', '知道'],
#  ['才', '能', '讀書', '、', '工作', '、', '服務', '社會'],
#  ['媽媽', '牽', '著', '我', '的', '手', '說'],
#  ['你', '看'],
#  ['身體', '健康', '多麼', '重要', '啊'],
#  ['你', '知道', '嗎'],
#  ['西方', '有', '句', '話', '說'],
#  ['寧願', '做', '一個', '健康', '的', '乞丐'],
#  ['也', '不要', '做', '一個', '生病', '的', '國王'],
#  ['這次', '跟', '媽媽', '到', '醫院', '探病'],
#  ['不但', '安慰', '了', '小', '阿姨'],
#  ['也', '讓', '我', '體會', '了', '健康', '的', '重要'],
#  ['十'],
#  ['孝子泉'],
#  ['大福', '是', '個', '孝順', '的', '孩子'],
#  ['有一次'],
#  ['他', '的', '父親', '得', '了', '怪病'],
#  ['身上', '長滿', '又', '紅', '又', '腫', '的', '斑塊'],
#  ['整天', '痛苦', '的', '呻吟', '著'],
#  ['大福', '焦急', '的', '背', '著', '父親', '到處', '看病'],
#  ['花', '了', '不少', '錢'],
#  ['病情', '卻', '依然', '沒有', '起色'],
#  ['一天', '晚上'],
#  ['大福', '靠在', '父親', '的', '床', '邊', '打瞌睡'],
#  ['忽', '聽到', '有', '人', '唱', '著'],
#  ['千種', '病'],
#  ['萬種', '病'],
#  ['神醫', '能', '治', '奇怪', '病'],
#  ['千座', '山'],
#  ['萬座', '山'],
#  ['神醫', '就', '在', '安平山'],
#  ['大福', '聽到', '了', '歌聲'],
#  ['決定', '天', '一', '亮'],
#  ['就', '上山', '去', '找', '神醫'],
#  ['隔天', '一大早'],
#  ['大福', '背', '著', '父親', '向', '山', '上', '走去'],
#  ['一路', '上'],
#  ['長長', '的', '芒草'],
#  ['割破', '了', '大福', '的', '手腳'],
#  ['粗糙', '的', '石塊'],
#  ['刺穿', '了', '他', '的', '草鞋'],
#  ['背', '上', '的', '父親'],
#  ['似乎', '越來越', '重', '了'],
#  ['可是'],
#  ['大福', '仍然', '盡力', '的', '向', '前', '走'],
#  ['一心', '只', '想', '找到', '神醫'],
#  ['為', '父親', '治病'],
#  ['到了', '安平山', '山頂'],
#  ['坐', '著', '一個', '老人'],
#  ['就', '過去', '向', '他', '說明', '來意'],
#  ['老人', '緊閉', '著', '雙眼', '不', '說話'],
#  ['大福', '跪', '在', '地上'],
#  ['一面', '流淚'],
#  ['一面', '苦苦', '的', '哀求'],
#  ['老人', '被', '大福', '的', '孝心', '感動'],
#  ['便', '給', '了', '大福', '一粒', '金色', '的', '丸子'],
#  ['叫', '他', '把', '金丸', '丟進', '山泉', '裡'],
#  ['再', '讓', '父親', '下去', '浸泡'],
#  ['就', '能', '治好', '父親', '的', '病', '了'],
#  ['大福', '依照', '老人', '的', '指示', '去', '做'],
#  ['村子', '裡', '的', '山泉'],
#  ['成', '了', '熱騰騰', '的', '溫泉'],
#  ['身上', '長', '著', '斑塊', '的', '病人'],
#  ['泡', '在', '溫', '的', '泉水', '中'],
#  ['覺得', '既', '輕鬆', '又', '舒服'],
#  ['大家', '都', '很', '感謝', '大福'],
#  ['便', '把', '這個', '溫泉', '命名為', '孝子泉'],
#  ['十一'],
#  ['給', '堂弟', '的', '一封', '信'],
#  ['親愛', '的', '聖耀', '堂弟'],
#  ['接到', '你', '的', '來信'],
#  ['才', '知道', '嬸嬸', '被', '車子', '撞傷', '了'],
#  ['不知道', '嬸嬸', '的', '傷勢', '如何'],
#  ['我們', '都', '很', '擔心'],
#  ['希望', '她', '很', '快', '就', '會', '康復'],
#  ['上', '星期'],
#  ['老師', '說', '了', '一則', '孝行獎', '的', '故事'],
#  ['讓', '我們', '非常', '感動'],
#  ['孝行獎', '的', '得獎人', '中'],
#  ['有', '七十歲', '的', '老先生'],
#  ['也', '有', '十二歲', '的', '小孩子'],
#  ['每一位', '得獎人'],
#  ['都', '有一段', '感人', '的', '故事'],
#  ['其中', '有一個', '高中生'],
#  ['他', '看起來', '很', '瘦弱'],
#  ['卻', '做', '了', '許多', '令', '人', '欽佩', '的', '事'],
#  ['他', '的', '父母', '雙眼', '失明'],
#  ['靠著', '微薄', '的', '救濟金', '生活'],
#  ['所以'],
#  ['從小', '時候', '開始'],
#  ['他', '就', '扛起', '了', '照顧', '家人', '的', '責任'],
#  ['他', '經常', '帶', '著', '眼盲', '的', '父母'],
#  ['外出', '工作', '和', '購買', '東西'],
#  ['放學', '回家'],
#  ['除了', '看顧', '年幼', '的', '弟弟'],
#  ['還要', '做', '家事'],
#  ['直到', '夜深人靜'],
#  ['才', '能', '做', '學校', '的', '功課'],
#  ['他', '雖然', '每天', '很', '疲累'],
#  ['但是', '從不', '抱怨'],
#  ['十幾年', '來'],
#  ['他', '盡心', '盡力', '的', '照顧', '父母', '和', '弟弟'],
#  ['鄰居', '和', '朋友', '都', '讚美', '他'],
#  ['說', '他', '乖巧', '又', '懂事'],
#  ['他', '不僅', '是', '父母', '生活', '中的', '眼睛', '和', '雙手'],
#  ['更', '是', '大家', '心目中', '的', '好', '孩子'],
#  ['聽完', '老師', '講', '的', '故事'],
#  ['我', '的', '心', '裡', '好感', '動'],
#  ['也', '很', '佩服', '他', '的', '孝行'],
#  ['聖耀', '堂弟'],
#  ['你', '是否', '也', '有', '相同', '的', '感受', '呢'],
#  ['天氣', '越來越', '涼', '了'],
#  ['別', '忘', '了', '也', '要', '好好', '照顧', '自己', '喔'],
#  ['祝', '健康', '快樂'],
#  ['堂哥', '立宇', '上'],
#  ['10月', '5日'],
#  ['十二'],
#  ['詩選'],
#  ['憶', '母'],
#  ['倪瑞璿'],
#  ['河', '廣', '難', '航', '莫', '我', '過'],
#  ['未知', '安', '否', '近', '如何'],
#  ['暗中', '時', '滴', '思親', '淚'],
#  ['只', '恐', '思', '兒', '淚', '更多'],
#  ['遊子吟'],
#  ['孟郊'],
#  ['慈母', '手', '中線'],
#  ['遊子', '身上', '衣'],
#  ['臨行', '密密', '縫'],
#  ['意恐', '遲遲', '歸'],
#  ['誰', '言', '寸', '草', '心'],
#  ['報', '得', '三', '春', '暉'],
#  ['十三'],
#  ['木匠', '畫家', '齊白石'],
#  ['民國', '十一年'],
#  ['中', '日', '聯合', '畫展'],
#  ['一位', '名', '不', '見', '經', '傳', '的', '中國', '畫家'],
#  ['成為', '大家', '注目', '的', '焦點'],
#  ['當時'],
#  ['他', '的', '作品', '與', '生活', '情形', '被', '拍成', '了', '電影'],
#  ['接著'],
#  ['他', '又', '參加', '巴黎', '藝術', '展覽會'],
#  ['成', '了', '名聞', '國際', '的', '大', '畫家'],
#  ['他'],
#  ['就是', '生於', '清朝', '末年', '的', '齊白石'],
#  ['齊白石', '是', '一個', '農家', '子弟'],
#  ['父親', '想', '教', '他', '種田'],
#  ['但', '他', '身體', '瘦弱'],
#  ['無法', '勝任'],
#  ['只好', '送', '他去', '學', '木工'],
#  ['先', '做', '一般', '的', '桌子', '椅子'],
#  ['後來', '改學', '雕花', '的', '細', '木工'],
#  ['改變', '一些', '新', '花樣'],
#  ['因此', '名氣', '漸漸', '傳開'],
#  ['齊白石', '在', '朋友', '家', '見到', '一本', '芥子園', '畫譜'],
#  ['才', '發現', '自己', '過去', '畫', '人'],
#  ['不是', '頭', '太', '大'],
#  ['就是', '腳', '太', '長'],
#  ['畫', '花'],
#  ['不是', '花', '太', '肥'],
#  ['就是', '葉', '太', '瘦'],
#  ['向', '主人', '借', '了', '書'],
#  ['利用', '晚上'],
#  ['將', '畫譜', '上', '的', '畫'],
#  ['一幅', '一幅', '的', '勾畫', '下來'],
#  ['如此'],
#  ['他', '的', '雕花', '圖案', '就', '更', '富有', '變化', '了'],
#  ['齊白石', '學習', '工筆', '的', '花鳥畫', '時'],
#  ['就', '在', '家', '裡', '養', '了', '許多', '蜻蜓', '、', '蝴蝶', '、', '蜜蜂'],
#  ['他', '細心', '觀察', '牠們', '的', '生活', '動態'],
#  ['不斷', '的', '練習', '寫生'],
#  ['據說', '他', '把', '蝗蟲', '的', '寫生', '稿', '放', '在', '地上'],
#  ['可以', '引起', '群', '雞', '撲啄', '呢'],
#  ['除了', '畫畫'],
#  ['運用', '在', '刻印', '章', '上'],
#  ['練習', '刻印', '時'],
#  ['他', '把', '印章', '刻', '了', '又', '磨'],
#  ['磨', '了', '又', '刻'],
#  ['後來', '成', '了', '刻印', '的', '大師'],
#  ['齊白石', '二十七歲', '才', '開始', '正式', '學', '畫'],
#  ['六十六歲', '時'],
#  ['他', '到', '北平', '藝術', '學院', '教書'],
#  ['將', '富有', '鄉土', '氣息', '的', '畫風'],
#  ['一個', '貧窮', '的', '小', '木匠'],
#  ['經過', '不斷', '的', '努力'],
#  ['不斷', '的', '上進'],
#  ['終於', '成', '了', '名', '留', '畫史', '、', '聞名', '中外', '的', '大', '畫家'],
#  ['十四'],
#  ['四', '時', '都', '是', '讀書', '天'],
#  ['春天', '讀', '唐詩'],
#  ['床', '前', '明月', '光'],
#  ['疑', '是', '地上', '霜'],
#  ['李白', '清新', '的', '詩', '令', '人', '喜愛'],
#  ['鐵', '杵', '磨成', '繡花針', '的', '啟示'],
#  ['激發', '他', '努力', '學習'],
#  ['創作', '許多', '的', '詩歌'],
#  ['夏日', '在', '樹', '下'],
#  ['閱讀', '牛頓', '的', '傳記'],
#  ['由', '蘋果', '到', '萬有引力'],
#  ['他', '不斷', '的', '實驗'],
#  ['不斷', '的', '研究'],
#  ['使', '科學', '邁進', '一大步'],
#  ['秋天', '的', '午後'],
#  ['坐在', '草地', '上'],
#  ['看書', '法', '家', '懷素', '的', '故事'],
#  ['他', '揮著汗'],
#  ['頂', '著', '風'],
#  ['在', '芭蕉', '上', '辛勤', '練字'],
#  ['成為', '一', '代', '草書', '大師'],
#  ['寒冬', '的', '夜晚'],
#  ['在', '燈火', '下'],
#  ['看', '愛迪生', '的', '發明', '事蹟'],
#  ['他', '花', '了', '十三個', '月', '的', '時間'],
#  ['實驗', '了', '一', '千', '六', '百', '種', '材料'],
#  ['發明', '電燈', '照亮', '了', '世界'],
#  ['只有', '不斷', '的', '努力', '學習'],
#  ['才', '能', '增加', '我們', '的', '知識'],
#  ['開拓', '我們', '的', '視野'],
#  ['十五'],
#  ['光', '之', '天使'],
#  ['在', '沒有', '色彩', '、', '沒有', '聲音', '、', '沒有', '亮光', '的', '世界', '中', '生活'],
#  ['是', '一件', '痛苦', '的', '事情'],
#  ['海倫凱勒', '卻', '克服', '了', '它'],
#  ['海倫', '一歲半', '時'],
#  ['變成', '了', '不僅', '不能', '聽', '、', '不能', '看'],
#  ['而且', '無法', '說話', '的', '多重', '障礙', '者'],
#  ['從此'],
#  ['海倫', '的', '脾氣', '變', '得', '非常', '暴躁'],
#  ['行為', '變', '得', '非常', '任性'],
#  ['直到', '蘇利文', '小姐', '當', '了', '她', '的', '家庭', '教師'],
#  ['用', '無比', '的', '耐心', '和', '堅持'],
#  ['才', '慢慢', '的', '改變', '了', '海倫', '的', '脾氣'],
#  ['蘇利文', '小姐', '以', '手指', '代', '筆'],
#  ['教', '海倫', '洋娃娃', '、', '坐下', '、', '帽子', '等', '字'],
#  ['當', '教', '她', '水', '字', '時'],
#  ['同時', '讓', '海倫', '摸到', '冰冷', '而', '流動', '的', '水'],
#  ['海倫', '才', '知道'],
#  ['每一樣', '東西', '都', '有名', '字'],
#  ['她', '開始', '用心', '的', '去', '認識', '這個', '世界'],
#  ['海倫', '利用', '點字', '來看', '書'],
#  ['利用', '手語', '來', '表達', '自己', '的', '意思'],
#  ['她', '最', '大', '的', '希望', '是', '進入', '最好', '的', '大學'],
#  ['許多', '朋友', '都', '認為', '是', '不可能', '的', '事'],
#  ['蘇利文', '小姐', '陪', '著', '海倫', '不斷', '的', '努力', '用功'],
#  ['終於', '使得', '海倫', '考進', '了', '哈佛', '大學'],
#  ['不僅', '美國人', '大為', '震驚'],
#  ['甚至', '全', '世界', '的', '人', '都', '驚訝不已'],
#  ['海倫', '畢業', '後'],
#  ['到', '各', '地', '演講'],
#  ['她', '發覺到', '只', '用', '手語'],
#  ['沒辦法', '充分', '表露', '自己', '的', '心情'],
#  ['又', '花', '了', '三年', '的', '時間', '學說', '話'],
#  ['表達', '自己', '的', '意思'],
#  ['海倫', '克服', '了', '許多', '的', '困難'],
#  ['以', '親身', '的', '痛苦', '經驗'],
#  ['鼓勵', '不幸', '的', '人'],
#  ['勇敢', '的', '站起來'],
#  ['海倫', '帶給', '他們', '光明', '的', '希望'],
#  ['光', '之', '天使', '就是', '世人', '對', '她', '的', '尊稱'],
#  ['十六'],
#  ['汽車', '的', '聯想'],
#  ['五月', '十五日', '星期一'],
#  ['天氣', '晴'],
#  ['跟', '平常', '一樣'],
#  ['早上', '七點鐘'],
#  ['我', '坐', '爸爸', '的', '車子', '去', '學校'],
#  ['今天'],
#  ['馬路', '上', '的', '車子', '好多'],
#  ['我', '覺得', '馬路', '變成', '一條', '長長', '的', '河流'],
#  ['而', '車子', '就', '像', '一條條', '彩色', '的', '魚'],
#  ['它們', '在', '河', '裡', '川流不息', '的', '游', '著'],
#  ['真是', '有趣', '極了'],
#  ['爸'],
#  ['汽車', '是', '誰', '發明', '的'],
#  ['我', '突然', '想起', '這個', '問題'],
#  ['便', '把', '這個', '問題', '當作', '一個', '球'],
#  ['投給', '了', '爸爸'],
#  ['想不到', '爸爸', '很', '快', '的', '把', '球', '丟還', '給', '我'],
#  ['要', '我', '自己', '去', '找', '資料'],
#  ['利用', '午休', '時間'],
#  ['我', '到', '圖書館'],
#  ['看', '了', '幾本', '跟', '車子', '有關', '的', '書'],
#  ['我', '才', '發現到'],
#  ['人類', '是', '多麼', '了不起'],
#  ['以前', '人們', '要', '到', '一個', '地方'],
#  ['必須', '靠', '兩隻', '腳', '走路'],
#  ['非常', '的', '不', '方便'],
#  ['因此', '有', '人', '一', '輩子', '都', '沒', '離開', '過', '他', '的', '家鄉'],
#  ['人們', '一直', '動著腦筋'],
#  ['想', '利用', '機器', '代替', '人力'],
#  ['於是', '發明', '了', '輪子'],
#  ['使', '整個', '世界', '都', '滾動', '起來', '了'],
#  ['牛車', '、', '馬車', '、', '蒸汽', '火車', '、', '腳踏車', '、', '電車'],
#  ['陸陸續續', '被', '製造出來'],
#  ['發明', '汽車', '了'],
#  ['汽車', '可', '不是', '一個', '人', '所', '發明', '的'],
#  ['而是', '許多', '國家', '、', '許多', '人'],
#  ['經過', '多年', '不斷', '的', '研究', '和', '努力'],
#  ['才', '共同', '製造', '來', '的'],
#  ['汽車', '剛', '出現', '時'],
#  ['它', '有一個', '很', '奇怪', '的', '名字'],
#  ['叫', '無', '馬', '的', '馬車'],
#  ['吃', '過', '晚飯'],
#  ['爸爸', '聽', '了', '我', '的', '報告'],
#  ['滿意', '的', '點著頭'],
#  ['媽媽', '卻', '提醒', '我'],
#  ['汽車', '的', '發明'],
#  ['雖', '帶給', '人們', '生活', '上', '很', '大', '的', '方便'],
#  ['也', '帶來', '一些', '禍害'],
#  ['像', '觸目驚心', '的', '車禍'],
#  ['日益', '嚴重', '的', '汙染', '問題'],
#  ['媽媽', '的話'],
#  ['使', '我', '的', '想像力', '飛起來', '了'],
#  ['如果', '我', '發明', '一種', '低', '汙染', '、', '零', '車禍', '的', '汽車'],
#  ['我', '就是', '一個', '了不起', '的', '發明家', '了'],
#  ['十七'],
#  ['魯班', '的', '故事'],
#  ['公輸班', '是', '春秋', '時代', '的', '魯國人'],
#  ['又', '稱為', '魯班'],
#  ['他', '小', '的', '時候'],
#  ['就', '很', '喜歡', '觀察'],
#  ['觀察', '大人', '煮飯', '、', '織布', '、', '蓋', '房子'],
#  ['他', '都', '看', '得很', '仔細'],
#  ['他', '不僅', '認真', '的', '看'],
#  ['用心', '的', '想'],
#  ['還', '做', '一些', '精巧', '有用', '的', '東西'],
#  ['鄰居', '都', '稱讚', '他', '是', '個', '巧', '童'],
#  ['魯班', '長大', '了'],
#  ['當', '一名', '木工'],
#  ['他', '在', '木材', '上', '畫線', '時'],
#  ['總是', '自己', '拿', '著', '線', '的', '一', '端'],
#  ['請', '母親', '拿', '著', '線', '的', '另', '一', '端'],
#  ['才', '能', '畫出', '線', '來'],
#  ['他', '做', '了', '一個', '彎', '鉤'],
#  ['只要', '鉤', '在', '木材', '上'],
#  ['一個', '人', '就', '可以', '畫線'],
#  ['這個', '工具', '就是', '墨斗'],
#  ['在', '刨', '木', '時'],
#  ['魯班', '都', '要', '請', '他', '的', '妻子', '扶', '著', '木材'],
#  ['才', '能', '完成', '刨', '木', '的', '工作'],
#  ['有一次', '要', '刨', '木', '時'],
#  ['他', '便', '放', '了', '一塊', '短', '木頭', '頂住', '木材'],
#  ['一個', '人', '就', '可以', '刨', '木', '了'],
#  ['於是', '橛子', '被', '發明', '了'],
#  ['魯班', '帶', '著', '學徒', '上山', '去', '伐木'],
#  ['一', '不', '小心'],
#  ['他', '的', '手', '被', '芒草', '的', '葉子', '割傷', '了'],
#  ['他', '很', '仔細', '的', '觀察', '那片', '葉子'],
#  ['發現', '這種', '葉緣', '的', '鋸齒'],
#  ['像', '刀子', '一樣', '鋒利'],
#  ['魯班', '便', '模仿', '著', '芒草', '的', '葉緣'],
#  ['先', '用', '竹片', '做成', '鋸齒', '的', '樣子'],
#  ['在', '一棵', '小', '樹幹', '上', '鋸', '著'],
#  ['居然', '在', '樹幹', '上', '留下', '了', '一道', '深溝'],
#  ['他', '更', '有', '信心', '了'],
#  ['他', '把', '長', '鐵片', '打造成', '鋸齒', '的', '樣子'],
#  ['再', '和', '學徒', '各', '抓住', '長', '鐵片', '的', '一', '端'],
#  ['靠著', '樹幹', '來來回回', '的', '拉', '著'],
#  ['沒', '多久'],
#  ['就', '把', '一棵', '大樹', '鋸斷', '了'],
#  ['人們', '有', '了', '鋸子'],
#  ['魯班', '喜歡', '觀察'],
#  ['並且', '動手', '去', '做'],
#  ['這種', '創造', '與', '發明', '的', '精神'],
#  ['使', '他', '在', '兩千多年', '前', '所', '發明', '的', '一些', '工具'],
#  ['一直', '流傳', '到', '今天'],
#  ['所以', '他', '成為', '我國', '古代', '手藝', '精湛', '的', '巧', '匠'],
#  ['也', '為', '中國', '歷史', '留下', '永', '不', '褪色', '的', '一頁'],
#  ['十八'],
#  ['未來', '的', '生活'],
#  ['未來', '的', '生活', '是', '科技', '的', '、', '安全', '的', '、', '舒適', '的'],
#  ['這樣', '的', '生活', '可能', '實現', '嗎'],
#  ['可能', '的'],
#  ['因為',
#   '人類',
#   '會',
#   '善用',
#   '他們',
#   '的',
#   '天賦',
#   '聰明',
#   '的',
#   '頭腦',
#   '和',
#   '靈巧',
#   '的',
#   '雙手'],
#  ['去', '創造', '很多', '東西'],
#  ['使', '我們', '未來', '的', '生活', '更', '美好'],
#  ['如果', '創造', '萬能', '的', '機器人'],
#  ['那麼', '人類', '未來', '的', '生活', '會', '更', '舒適'],
#  ['萬能', '機器人', '是', '全家', '的', '好', '幫手'],
#  ['幫', '媽媽', '做', '家事'],
#  ['幫', '爸爸', '打', '電腦'],
#  ['還', '陪', '弟弟', '玩耍'],
#  ['接送', '姊姊', '上下學'],
#  ['它', '不僅', '對', '主人', '忠心'],
#  ['還', '全年', '無休', '呢'],
#  ['如果', '能', '發明', '神奇', '的', '守護神'],
#  ['那麼', '人類', '未來', '的', '生活', '會', '更', '安全'],
#  ['神奇', '的', '守護神'],
#  ['是', '一個', '圓形', '的', '小球'],
#  ['可', '掛', '在', '人們', '的', '胸', '前'],
#  ['上街', '迷路', '了', '或', '走失', '了'],
#  ['可以', '按', '一下', '胸', '前', '的', '小球'],
#  ['附近', '警察局', '的', '網路', '上'],
#  ['就', '會', '接受到', '訊息'],
#  ['警察', '人員', '會', '及時', '趕過來', '幫忙'],
#  ['遇到', '歹徒', '時'],
#  ['趕快', '按', '一下', '胸', '前', '的', '小球'],
#  ['歹徒', '的', '容貌', '會', '被', '輸送', '到', '警察局', '的', '網路', '上'],
#  ['警察', '人員', '會', '以', '最', '快', '的', '速度', '趕到', '現場'],
#  ['再', '狡猾', '的', '歹徒', '也', '插翅難飛', '了'],
#  ['如果', '利用', '科技', '發明', '一些', '東西'],
#  ['那麼', '人類', '未來', '的', '生活', '會', '更', '方便'],
#  ['倘若', '發明', '空氣', '調節器'],
#  ['早上', '一', '醒來', '就', '可以', '呼吸到', '新鮮', '的', '空氣'],
#  ['而且', '空氣', '的', '味道', '可以', '隨', '個人', '喜好', '調整'],
#  ['像', '牛奶', '、', '草莓', '、', '花香'],
#  ['倘若', '發明', '自動', '調整', '溫度', '的', '帳篷'],
#  ['出外', '旅遊'],
#  ['只要', '隨身', '帶', '著', '它'],
#  ['都', '可以', '成為', '露營', '的', '好', '地方', '了'],
#  ['有', '人', '說', '頭腦', '是', '思想家'],
#  ['雙手', '是', '實行家'],
#  ['也', '不錯'],
#  ['讓', '它們', '充分', '合作'],
#  ['去', '創造', '、', '去', '發明'],
#  ['可以', '拓展', '我們', '的', '生活', '領域'],
#  ['提高', '我們', '的', '生活', '品質'],
#  ['使', '未來', '的', '生活', '美', '夢', '成真'],
#  ['成長', '的', '喜悅'],
#  ['星期六', '下午'],
#  ['我', '在', '寫', '功課', '時'],
#  ['哥哥', '走過來'],
#  ['愁眉苦臉', '的', '說'],
#  ['妹'],
#  ['這個', '月', '量', '身高'],
#  ['我', '居然', '沒', '長高'],
#  ['哥'],
#  ['你', '大', '我', '三歲'],
#  ['已經', '高出', '我', '一個', '頭', '了'],
#  ['我', '還', '比不上', '我', '班', '上', '的', '阿泰'],
#  ['他', '不僅', '長', '得', '高', '、', '長', '得', '壯'],
#  ['還', '長出', '了', '小', '鬍子'],
#  ['就', '像', '漫畫書', '中的', '翩翩', '美', '少年'],
#  ['你', '班', '上', '已經', '有', '人', '長', '鬍子', '啦'],
#  ['這時', '媽媽', '回來', '了'],
#  ['她', '聽見', '我們', '的', '談話'],
#  ['覺得', '很', '有趣'],
#  ['摟', '著', '我們', '說'],
#  ['長大', '了'],
#  ['生理', '上', '、', '心理', '上', '都會', '有', '變化', '的'],
#  ['你們', '想', '知道', '身體', '的', '變化', '嗎'],
#  ['社教館', '正好', '有一個', '認識', '身體', '的', '展覽'],
#  ['明天', '我們', '一起', '去', '參觀'],
#  ['探索', '一下', '青春期', '的', '身體', '變化'],
#  ['第二天'],
#  ['我們', '一家人', '到', '社教館', '去'],
#  ['看到', '展覽區', '分為', '幼兒區', '、', '青春區', '和', '中老年區'],
#  ['我們', '直接', '到', '青春區', '參觀'],
#  ['這', '是', '多媒體', '的', '展覽'],
#  ['有', '聲光'],
#  ['也', '有', '活動'],
#  ['一面', '牆', '上', '掛', '著', '各式', '圖片', '和', '照片'],
#  ['另一面', '有', '電影'],
#  ['還', '有', '電腦', '人體', '分析', '圖'],
#  ['我', '一面', '看', '著', '圖片'],
#  ['一面', '讀', '著', '文字'],
#  ['對', '青春期', '的', '男生', '、', '女生', '身體', '的', '變化'],
#  ['有', '了', '初步', '的', '認識'],
#  ['也', '覺得', '身體', '的', '成長', '是', '自然', '而', '神祕', '的'],
#  ['而且', '知道'],
#  ['再', '過', '幾年', '我', '就', '可以', '長高', '十公分'],
#  ['變成', '亭亭玉立', '的', '美', '少女', '了'],
#  ['回家', '的', '路', '上'],
#  ['我', '想起', '好友', '容玉'],
#  ['她', '對', '自己', '的', '身體', '也', '有', '一些', '好奇', '和', '不解'],
#  ['我', '希望', '把', '這個', '訊息', '告訴', '她'],
#  ['於是', '我', '迫不及待', '的', '奔向', '她', '家'],
#  ['結果', '她', '去', '舅舅', '家', '了'],
#  ['因此', '我', '留', '了', '一張', '便條', '給', '她'],
#  ['容玉'],
#  ['早上'],
#  ['我們', '全家', '去', '社教館'],
#  ['參觀', '了', '認識', '身體', '的', '多媒體', '展覽'],
#  ['我', '覺得', '獲益良多'],
#  ['希望', '妳', '能', '抽空', '去', '看看'],
#  ['讓', '我們', '一起', '分享', '成長', '的', '喜悅'],
#  ['晴芳', '上'],
#  ['二月', '二十日'],
#  ['山豬', '的', '尾巴', '捲起來', '了'],
#  ['在', '一座', '廣大', '的', '森林', '裡'],
#  ['住', '了', '許多', '動物'],
#  ['其中', '有一隻', '山豬'],
#  ['全身', '黑黑', '的'],
#  ['樣子', '笨笨', '的'],
#  ['常常', '受到', '一些', '動物', '的', '嘲笑'],
#  ['看到', '山豬', '走過來'],
#  ['枝頭', '上', '的', '小鳥', '總是', '吱吱喳喳', '的', '叫'],
#  ['山豬', '長', '得', '黑'],
#  ['黑', '又', '黑'],
#  ['好像', '垃圾堆'],
#  ['看', '了', '會', '倒楣'],
#  ['草地', '上', '的', '兔子', '也', '會', '叫', '著'],
#  ['山豬', '嘴巴', '大'],
#  ['大', '又', '大'],
#  ['兩隻', '大', '獠牙'],
#  ['看', '了', '好', '害怕'],
#  ['山豬', '聽', '了', '好', '難過'],
#  ['他', '不', '喜歡', '身上', '的', '黑', '毛'],
#  ['冬天', '過', '了'],
#  ['春神', '把', '森林', '變', '得', '五顏六色', '、', '多彩多姿'],
#  ['獨自', '走', '在', '森林', '裡', '的', '山豬'],
#  ['也', '希望', '春神', '把', '他', '變', '得', '像', '獅子', '一樣', '的', '雄壯'],
#  ['山豬', '正', '想', '得', '開心', '的', '時候'],
#  ['忽然', '傳來', '了', '喊', '救命', '的', '聲音'],
#  ['山豬', '趕緊', '循', '著', '聲音', '跑過去'],
#  ['在', '一棵', '大樹', '下'],
#  ['看到', '一隻', '小', '鹿', '中', '了', '獵人', '的', '陷阱'],
#  ['被', '一張', '網子', '網住', '了'],
#  ['小', '鹿', '很', '害怕'],
#  ['不停', '的', '叫喊', '著'],
#  ['山豬', '連忙', '用', '他', '尖利', '的', '獠牙', '去', '撥開', '網子'],
#  ['撥', '呀', '撥', '的'],
#  ['終於', '把', '網子', '弄破', '了'],
#  ['救出', '了', '小', '鹿'],
#  ['小', '鹿', '一再', '的', '感謝', '山豬'],
#  ['從此', '以後'],
#  ['小鳥', '看到', '山豬', '走過來'],
#  ['他們', '會', '大聲', '的', '唱'],
#  ['山豬', '山豬', '好', '雄壯'],
#  ['全身', '黑', '毛', '會', '發亮'],
#  ['兩隻', '獠牙', '有力', '量'],
#  ['真是', '我們', '的', '偶像'],
#  ['山豬', '聽', '了'],
#  ['不僅', '笑開', '了', '大', '嘴'],
#  ['連', '尾巴', '都', '捲起來', '了'],
#  ['日記', '一則'],
#  ['魔鏡', '會', '說話'],
#  ['三月', '十日', '星期二'],
#  ['今天', '上', '說話課', '時'],
#  ['老師', '教', '我們', '玩', '魔鏡', '會', '說話', '的', '遊戲'],
#  ['我們', '高興', '得', '拍手', '歡呼'],
#  ['音樂聲', '響起'],
#  ['遊戲', '就', '開始', '了'],
#  ['每個', '同學', '的', '手', '上'],
#  ['都', '拿', '著', '紙', '做', '的', '半面', '鏡子'],
#  ['踩', '著', '輕快', '的', '腳步'],
#  ['在', '同學', '中', '尋找', '另外', '的', '半面', '鏡子'],
#  ['只要', '找到', '它'],
#  ['跟', '自己', '手', '上', '的', '半面', '鏡子', '合成', '一個', '圓'],
#  ['魔鏡', '就', '會', '出現', '了'],
#  ['我', '手', '上', '拿', '的', '半面', '鏡子'],
#  ['跟', '小山', '手', '上', '拿', '的', '半面', '鏡子'],
#  ['合成', '一個', '圓圓', '的', '魔鏡', '了'],
#  ['我們', '高興', '得', '抱', '在一起'],
#  ['做出', '勝利', '的', '姿勢'],
#  ['然後', '商量', '要', '讓', '魔鏡', '說', '些', '什麼', '話'],
#  ['輪到', '我', '和', '小山', '拿', '著', '魔鏡', '上臺'],
#  ['小山', '問', '魔鏡'],
#  ['魔鏡', '啊'],
#  ['魔鏡'],
#  ['誰', '是', '班', '上', '的', '超人'],
#  ['我', '故意', '壓低', '聲音'],
#  ['裝成', '老婆婆', '的', '聲音', '回答'],
#  ['是', '小山'],
#  ['小山', '長', '得', '壯'],
#  ['跑', '得', '快'],
#  ['又', '熱心', '助人'],
#  ['他', '當', '了', '超人', '之後'],
#  ['班', '上', '一年', '四', '季', '都', '平安'],
#  ['魔鏡', '說', '的話'],
#  ['引起', '同學', '的', '共鳴'],
#  ['臺', '下', '響起', '如雷', '的', '掌聲'],
#  ['想', '當', '超人', '的', '小山'],
#  ['咧開', '嘴', '笑'],
#  ['還', '做出', '超人', '要', '飛行', '的', '模樣'],
#  ['接下來', '是', '我', '問', '魔鏡'],
#  ['誰', '是', '班', '上', '的', '英雄'],
#  ['小山', '裝成', '老婆婆', '的', '聲音', '回答'],
#  ['是', '阿智'],
#  ['自從', '他', '找到', '今日', '事', '今日', '畢', '的', '寶劍', '之後'],
#  ['終於', '把', '那隻', '名叫', '拖拖拉拉', '的', '怪物', '除掉'],
#  ['使', '阿智', '變', '得', '勤快'],
#  ['而且', '功課', '也', '進步', '了'],
#  ['獲得', '許多', '同學', '的', '支持'],
#  ['大家', '看看', '我'],
#  ['給', '我', '讚美', '的', '掌聲'],
#  ['玩', '了', '這個', '遊戲'],
#  ['我', '認識', '了', '更多', '同學', '的', '優點'],
#  ['今天', '是', '充實', '而', '快樂', '的', '一天'],
#  ['感恩', '的', '日子'],
#  ['在', '美國', '東部'],
#  ['十一月', '的', '天空'],
#  ['飄', '著', '細細', '的', '白雪'],
#  ['屋', '裡', '的', '老約翰', '夫婦'],
#  ['正', '歡歡喜喜', '的', '忙著'],
#  ['他們', '準備', '了', '香噴噴', '的', '烤', '火雞', '、', '南瓜派'],
#  ['還', '有', '各式各樣', '美味', '的', '點心'],
#  ['等待', '與', '家人', '共', '度', '美好', '的', '感恩節'],
#  ['從', '各', '地', '回來', '的', '孩子們'],
#  ['和', '老約翰', '夫婦', '圍坐', '在', '桌', '邊'],
#  ['在', '溫暖', '的', '燈光', '下'],
#  ['他們', '先', '感謝', '上天', '的', '恩典'],
#  ['然後', '吃', '著', '豐盛', '的', '火雞', '大餐'],
#  ['全家', '大小', '有說有笑'],
#  ['吃完', '飯'],
#  ['大家', '圍', '著', '八十多歲', '的', '老爺爺'],
#  ['聽', '他', '說', '感恩節', '的', '故事'],
#  ['三百多年', '前'],
#  ['有', '一百多名', '英國人'],
#  ['搭乘', '五月花號', '木船'],
#  ['越過', '大西洋'],
#  ['尋找', '新', '的', '天地'],
#  ['他們', '經過', '了', '千辛萬苦'],
#  ['到達', '新大陸'],
#  ['當時', '天氣', '非常', '寒冷'],
#  ['又', '缺少', '食物'],
#  ...]

# %%
output_file = open("segmented.txt", "w")
for t in tokens:
    sentence = " ".join(t)
    output_file.write(sentence + "\n")
